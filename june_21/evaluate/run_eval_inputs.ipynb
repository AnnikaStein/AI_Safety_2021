# %%
import numpy as np

# %%
# !python eval_inputs.py 0 fgsm yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# Doing Jet $\eta$ now.
# -2.5340285396575926 2.5349645709991453
# [[[0, 0.01, 0.0004777361275126416], [0, 0.02, 0.0011097481447781784]]]
# findfont: Font family ['cursive'] not found. Falling back to DejaVu Sans.
# [[[0.         0.01       0.00047774]
#   [0.         0.02       0.00110975]]]
# Figure(1000x600)
# eval_inputs.py:391: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax1.set_ylim(bottom=None)
# eval_inputs.py:640: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax1.set_ylim(bottom=None)
# -2.5340285396575926 2.5349645709991453
# ...

# %%
# !python eval_inputs.py 0 fgsm yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0_adv_tr_eps0.01 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0_adv_tr_eps0.01
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['0.01']
# Loaded model and corresponding criterion.
# -2.5340285396575926 2.5349645709991453
# [[[0, 0.01, 0.000637024357101472], [0, 0.02, 0.0014459695398899434]]]
# findfont: Font family ['cursive'] not found. Falling back to DejaVu Sans.
# [[[0.         0.01       0.00063702]
#   [0.         0.02       0.00144597]]]
# Figure(1000x600)
# eval_inputs.py:348: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax1.set_ylim(bottom=None)
# -2.5340285396575926 2.5349645709991453
# [[[0, 0.01, 0.000637024357101472], [0, 0.02, 0.0014459695398899434]], [[0, 0.01, 0.000637024357101472], [0, 0.02, 0.0014459695398899434]]]
# [[[0.         0.01       0.00063702]
#   [0.         0.02       0.00144597]]
#
#  [[0.         0.01       0.00063702]
#   [0.         0.02       0.00144597]]]
# ...

# %%
# !python eval_inputs.py 0 fgsm yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 no
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.

# %%
print(np.load('inputs/kl_div/input_0_Jet_eta_fgsm[0, 0.01, 0.02]_spec_range_13283070__ptetaflavloss_focalloss_gamma25.0_200.npy'))
# Out:
# [[[0.         0.01       0.00025564]
#   [0.         0.02       0.00097858]]]

# %%
# !python eval_inputs.py 1 fgsm yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# Doing Jet $p_T$ now.
# 16.949428787231444 791.3431909179687
# eval_inputs.py:324: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:324: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:327: RuntimeWarning: divide by zero encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in multiply
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# ...

# %%
# !python eval_inputs.py 2 fgsm yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# Doing Flight Distance 2D Sig now.
# 1.3249030017852783 943.321767578125
# eval_inputs.py:324: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:324: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:327: RuntimeWarning: divide by zero encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in multiply
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# ...

# %%
# !python eval_inputs.py 3 fgsm yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# Doing Flight Distance 2D Val now.
# -0.009121074564754963 2.5195040798187254
# [[[3, 0.01, 0.00033962261799964954], [3, 0.02, 0.0016638510362994147]]]
# findfont: Font family ['cursive'] not found. Falling back to DejaVu Sans.
# [[[3.00000000e+00 1.00000000e-02 3.39622618e-04]
#   [3.00000000e+00 2.00000000e-02 1.66385104e-03]]]
# Figure(1000x600)
# eval_inputs.py:391: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax1.set_ylim(bottom=None)
# eval_inputs.py:504: RuntimeWarning: divide by zero encountered in true_divide
#   ratioBB = numBB / denomBB
# eval_inputs.py:519: RuntimeWarning: divide by zero encountered in true_divide
# ...

# %%
# !python eval_inputs.py 4 fgsm yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# Doing Flight Distance 3D Sig now.
# -0.45892898201942445 942.5071923828125
# eval_inputs.py:324: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:324: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:327: RuntimeWarning: divide by zero encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in multiply
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# ...

# %%
# !python eval_inputs.py 5 fgsm yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# Doing Flight Distance 3D Val now.
# -0.010193935717106797 14.943606147766113
# eval_inputs.py:324: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# [[[5, 0.01, 2.298405077879017e-05], [5, 0.02, 7.73814290988327e-05]]]
# findfont: Font family ['cursive'] not found. Falling back to DejaVu Sans.
# [[[5.00000000e+00 1.00000000e-02 2.29840508e-05]
#   [5.00000000e+00 2.00000000e-02 7.73814291e-05]]]
# Figure(1000x600)
# eval_inputs.py:391: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax1.set_ylim(bottom=None)
# ...

# %%
# !python eval_inputs.py 6 fgsm yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# Doing Track Decay Len Val [0] now.
# -0.023984037563204767 5.024389991760254
# [[[6, 0.01, 0.01121296837902526], [6, 0.02, 0.06433427761903941]]]
# findfont: Font family ['cursive'] not found. Falling back to DejaVu Sans.
# [[[6.         0.01       0.01121297]
#   [6.         0.02       0.06433428]]]
# Figure(1000x600)
# eval_inputs.py:391: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax1.set_ylim(bottom=None)
# eval_inputs.py:504: RuntimeWarning: divide by zero encountered in true_divide
#   ratioBB = numBB / denomBB
# eval_inputs.py:504: RuntimeWarning: invalid value encountered in true_divide
#   ratioBB = numBB / denomBB
# ...

# %%
# !python eval_inputs.py 7 fgsm yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# Doing Track Decay Len Val [1] now.
# -0.019469619020819666 5.020190010070801
# [[[7, 0.01, 0.0035744499230804393], [7, 0.02, 0.016758594353060634]]]
# findfont: Font family ['cursive'] not found. Falling back to DejaVu Sans.
# [[[7.00000000e+00 1.00000000e-02 3.57444992e-03]
#   [7.00000000e+00 2.00000000e-02 1.67585944e-02]]]
# Figure(1000x600)
# eval_inputs.py:391: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax1.set_ylim(bottom=None)
# eval_inputs.py:504: RuntimeWarning: divide by zero encountered in true_divide
#   ratioBB = numBB / denomBB
# eval_inputs.py:504: RuntimeWarning: invalid value encountered in true_divide
#   ratioBB = numBB / denomBB
# ...

# %%
# !python eval_inputs.py 8 fgsm yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# Doing Track Decay Len Val [2] now.
# -0.01763071654364467 5.017429599761963
# [[[8, 0.01, 0.0015400498018749492], [8, 0.02, 0.007097372361428648]]]
# findfont: Font family ['cursive'] not found. Falling back to DejaVu Sans.
# [[[8.00000000e+00 1.00000000e-02 1.54004980e-03]
#   [8.00000000e+00 2.00000000e-02 7.09737236e-03]]]
# Figure(1000x600)
# eval_inputs.py:391: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax1.set_ylim(bottom=None)
# eval_inputs.py:504: RuntimeWarning: divide by zero encountered in true_divide
#   ratioBB = numBB / denomBB
# eval_inputs.py:504: RuntimeWarning: invalid value encountered in true_divide
#   ratioBB = numBB / denomBB
# ...

# %%
# !python eval_inputs.py 9 fgsm yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# Doing Track Decay Len Val [3] now.
# -0.01655724760144949 5.017228374481201
# [[[9, 0.01, 0.0006813683789969225], [9, 0.02, 0.0029561596524442712]]]
# findfont: Font family ['cursive'] not found. Falling back to DejaVu Sans.
# [[[9.00000000e+00 1.00000000e-02 6.81368379e-04]
#   [9.00000000e+00 2.00000000e-02 2.95615965e-03]]]
# Figure(1000x600)
# eval_inputs.py:391: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax1.set_ylim(bottom=None)
# eval_inputs.py:504: RuntimeWarning: divide by zero encountered in true_divide
#   ratioBB = numBB / denomBB
# eval_inputs.py:504: RuntimeWarning: invalid value encountered in true_divide
#   ratioBB = numBB / denomBB
# ...

# %%
# !python eval_inputs.py 10 fgsm yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# Doing Track Decay Len Val [4] now.
# -0.017754302583634855 5.017345676422119
# [[[10, 0.01, 0.000810866439356445], [10, 0.02, 0.0036088863103722296]]]
# findfont: Font family ['cursive'] not found. Falling back to DejaVu Sans.
# [[[1.00000000e+01 1.00000000e-02 8.10866439e-04]
#   [1.00000000e+01 2.00000000e-02 3.60888631e-03]]]
# Figure(1000x600)
# eval_inputs.py:391: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax1.set_ylim(bottom=None)
# eval_inputs.py:503: RuntimeWarning: invalid value encountered in true_divide
#   ratioB  = numB / denomB
# eval_inputs.py:504: RuntimeWarning: invalid value encountered in true_divide
#   ratioBB = numBB / denomBB
# ...

# %%
# !python eval_inputs.py 11 fgsm yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# Doing Track Decay Len Val [5] now.
# -0.017704033982008698 5.017199764251709
# [[[11, 0.01, 0.0005334683102447936], [11, 0.02, 0.002365471353151573]]]
# findfont: Font family ['cursive'] not found. Falling back to DejaVu Sans.
# [[[1.10000000e+01 1.00000000e-02 5.33468310e-04]
#   [1.10000000e+01 2.00000000e-02 2.36547135e-03]]]
# Figure(1000x600)
# eval_inputs.py:391: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax1.set_ylim(bottom=None)
# eval_inputs.py:503: RuntimeWarning: divide by zero encountered in true_divide
#   ratioB  = numB / denomB
# eval_inputs.py:503: RuntimeWarning: invalid value encountered in true_divide
#   ratioB  = numB / denomB
# ...

# %%
# !python eval_inputs.py 12 fgsm yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# Doing Track $\Delta R$ [0] now.
# -0.011512385089881718 0.31173489451408387
# eval_inputs.py:324: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# [[[12, 0.01, 0.00022080822045473966], [12, 0.02, 0.0005567770034931834]]]
# findfont: Font family ['cursive'] not found. Falling back to DejaVu Sans.
# [[[1.20000000e+01 1.00000000e-02 2.20808220e-04]
#   [1.20000000e+01 2.00000000e-02 5.56777003e-04]]]
# Figure(1000x600)
# eval_inputs.py:391: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax1.set_ylim(bottom=None)
# ...

# %%
# !python eval_inputs.py 13 fgsm yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# Doing Track $\Delta R$ [1] now.
# -0.011365060918033123 0.31165186524391175
# eval_inputs.py:324: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# [[[13, 0.01, 0.0003114980379207233], [13, 0.02, 0.0009930883327644202]]]
# findfont: Font family ['cursive'] not found. Falling back to DejaVu Sans.
# [[[1.30000000e+01 1.00000000e-02 3.11498038e-04]
#   [1.30000000e+01 2.00000000e-02 9.93088333e-04]]]
# Figure(1000x600)
# eval_inputs.py:391: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax1.set_ylim(bottom=None)
# ...

# %%
# !python eval_inputs.py 14 fgsm yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# Doing Track $\Delta R$ [2] now.
# -0.011550712622702122 0.3116352653503418
# eval_inputs.py:324: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# [[[14, 0.01, 0.00022105052310252845], [14, 0.02, 0.0005603351443106597]]]
# findfont: Font family ['cursive'] not found. Falling back to DejaVu Sans.
# [[[1.40000000e+01 1.00000000e-02 2.21050523e-04]
#   [1.40000000e+01 2.00000000e-02 5.60335144e-04]]]
# Figure(1000x600)
# eval_inputs.py:391: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax1.set_ylim(bottom=None)
# ...

# %%
# !python eval_inputs.py 15 fgsm yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# Doing Track $\Delta R$ [3] now.
# -0.011710564829409123 0.31186915397644044
# eval_inputs.py:324: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# [[[15, 0.01, 0.0002308532105102199], [15, 0.02, 0.0003632647865588522]]]
# findfont: Font family ['cursive'] not found. Falling back to DejaVu Sans.
# [[[1.50000000e+01 1.00000000e-02 2.30853211e-04]
#   [1.50000000e+01 2.00000000e-02 3.63264787e-04]]]
# Figure(1000x600)
# eval_inputs.py:391: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax1.set_ylim(bottom=None)
# ...

# %%
# !python eval_inputs.py 16 fgsm yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# Doing Track $\Delta R$ [4] now.
# -0.011506593194790185 0.3117680048942566
# eval_inputs.py:324: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# [[[16, 0.01, 0.00022212722191891453], [16, 0.02, 0.00048304230472099056]]]
# findfont: Font family ['cursive'] not found. Falling back to DejaVu Sans.
# [[[1.60000000e+01 1.00000000e-02 2.22127222e-04]
#   [1.60000000e+01 2.00000000e-02 4.83042305e-04]]]
# Figure(1000x600)
# eval_inputs.py:391: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax1.set_ylim(bottom=None)
# ...

# %%
# !python eval_inputs.py 17 fgsm yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# Doing Track $\Delta R$ [5] now.
# -0.011311923027969897 0.311514208316803
# eval_inputs.py:324: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# [[[17, 0.01, 0.0001188951963462402], [17, 0.02, 0.00025472605279198816]]]
# findfont: Font family ['cursive'] not found. Falling back to DejaVu Sans.
# [[[1.70000000e+01 1.00000000e-02 1.18895196e-04]
#   [1.70000000e+01 2.00000000e-02 2.54726053e-04]]]
# Figure(1000x600)
# eval_inputs.py:391: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax1.set_ylim(bottom=None)
# ...

# %%
# !python eval_inputs.py 18 fgsm yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# Doing Track $\eta_{rel}$ [0] now.
# -4.791981945037842 8.321845779418945
# eval_inputs.py:324: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:324: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:327: RuntimeWarning: divide by zero encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in multiply
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# ...

# %%
# !python eval_inputs.py 19 fgsm yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# Doing Track $\eta_{rel}$ [1] now.
# -4.675261745452881 8.458081016540527
# eval_inputs.py:324: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:324: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:327: RuntimeWarning: divide by zero encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in multiply
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# ...

# %%
# !python eval_inputs.py 20 fgsm yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# Doing Track $\eta_{rel}$ [2] now.
# -3.9242050743103025 8.750593910217285
# eval_inputs.py:324: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# [[[20, 0.01, 2.5639720508042568e-05], [20, 0.02, 3.0016837743406775e-05]]]
# findfont: Font family ['cursive'] not found. Falling back to DejaVu Sans.
# [[[2.00000000e+01 1.00000000e-02 2.56397205e-05]
#   [2.00000000e+01 2.00000000e-02 3.00168377e-05]]]
# Figure(1000x600)
# eval_inputs.py:391: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax1.set_ylim(bottom=None)
# ...

# %%
# !python eval_inputs.py 21 fgsm yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# Doing Track $\eta_{rel}$ [3] now.
# -4.306250820159912 8.024421463012695
# eval_inputs.py:324: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# [[[21, 0.01, 1.4759341898536987e-05], [21, 0.02, 1.594727419587449e-05]]]
# findfont: Font family ['cursive'] not found. Falling back to DejaVu Sans.
# [[[2.10000000e+01 1.00000000e-02 1.47593419e-05]
#   [2.10000000e+01 2.00000000e-02 1.59472742e-05]]]
# Figure(1000x600)
# eval_inputs.py:391: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax1.set_ylim(bottom=None)
# ...

# %%
# !python eval_inputs.py 22 fgsm yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# Doing Track Jet Dist Val [0] now.
# -0.08102172821760177 0.01028298280085437
# eval_inputs.py:324: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:324: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:327: RuntimeWarning: divide by zero encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in multiply
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# ...

# %%
# !python eval_inputs.py 23 fgsm yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# Doing Track Jet Dist Val [1] now.
# -0.08100672274827957 0.010418992451159284
# eval_inputs.py:324: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:324: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:327: RuntimeWarning: divide by zero encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in multiply
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# ...

# %%
# !python eval_inputs.py 24 fgsm yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# Doing Track Jet Dist Val [2] now.
# -0.0810114762187004 0.010560332904569805
# eval_inputs.py:324: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:324: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:327: RuntimeWarning: divide by zero encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in multiply
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# ...

# %%
# !python eval_inputs.py 25 fgsm yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# Doing Track Jet Dist Val [3] now.
# -0.08100782543420791 0.010648251036182046
# eval_inputs.py:324: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:324: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:327: RuntimeWarning: divide by zero encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in multiply
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# ...

# %%
# !python eval_inputs.py 26 fgsm yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# Doing Track Jet Dist Val [4] now.
# -0.08101457566022872 0.010684602069668472
# eval_inputs.py:324: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:324: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:327: RuntimeWarning: divide by zero encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in multiply
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# ...

# %%
# !python eval_inputs.py 27 fgsm yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# Doing Track Jet Dist Val [5] now.
# -0.08099969685077667 0.010657651049550623
# eval_inputs.py:324: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:324: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:327: RuntimeWarning: divide by zero encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in multiply
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# ...

# %%
# !python eval_inputs.py 28 fgsm yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# Doing Track Jet $p_T$ now.
# -1.3933446502685547 253.74667907714843
# eval_inputs.py:324: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# [[[28, 0.01, 0.0007420838094456198], [28, 0.02, 0.0010605279524585716]]]
# findfont: Font family ['cursive'] not found. Falling back to DejaVu Sans.
# [[[2.80000000e+01 1.00000000e-02 7.42083809e-04]
#   [2.80000000e+01 2.00000000e-02 1.06052795e-03]]]
# Figure(1000x600)
# eval_inputs.py:391: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax1.set_ylim(bottom=None)
# ...

# %%
# !python eval_inputs.py 29 fgsm yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# Doing Track $p_{T,rel}$ Ratio [0] now.
# -0.01123512337449938 0.30620373249053956
# eval_inputs.py:324: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# [[[29, 0.01, 0.0001928488158116316], [29, 0.02, 0.000695731152244568]]]
# findfont: Font family ['cursive'] not found. Falling back to DejaVu Sans.
# [[[2.90000000e+01 1.00000000e-02 1.92848816e-04]
#   [2.90000000e+01 2.00000000e-02 6.95731152e-04]]]
# Figure(1000x600)
# eval_inputs.py:391: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax1.set_ylim(bottom=None)
# ...

# %%
# !python eval_inputs.py 30 fgsm yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# Doing Track $p_{T,rel}$ Ratio [1] now.
# -0.01126370508223772 0.30669013619422913
# eval_inputs.py:324: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# [[[30, 0.01, 0.0002986909689997186], [30, 0.02, 0.0010525155513526289]]]
# findfont: Font family ['cursive'] not found. Falling back to DejaVu Sans.
# [[[3.00000000e+01 1.00000000e-02 2.98690969e-04]
#   [3.00000000e+01 2.00000000e-02 1.05251555e-03]]]
# Figure(1000x600)
# eval_inputs.py:391: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax1.set_ylim(bottom=None)
# ...

# %%
# !python eval_inputs.py 31 fgsm yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# Doing Track $p_{T,rel}$ Ratio [2] now.
# -0.011204385771416128 0.3064513897895813
# eval_inputs.py:324: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# [[[31, 0.01, 0.00014496896587717347], [31, 0.02, 0.00035803500645205236]]]
# findfont: Font family ['cursive'] not found. Falling back to DejaVu Sans.
# [[[3.10000000e+01 1.00000000e-02 1.44968966e-04]
#   [3.10000000e+01 2.00000000e-02 3.58035006e-04]]]
# Figure(1000x600)
# eval_inputs.py:391: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax1.set_ylim(bottom=None)
# ...

# %%
# !python eval_inputs.py 32 fgsm yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# Doing Track $p_{T,rel}$ Ratio [3] now.
# -0.011123694470152259 0.3064294254779816
# eval_inputs.py:324: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# [[[32, 0.01, 0.00014748902521581834], [32, 0.02, 0.0004532055708982819]]]
# findfont: Font family ['cursive'] not found. Falling back to DejaVu Sans.
# [[[3.20000000e+01 1.00000000e-02 1.47489025e-04]
#   [3.20000000e+01 2.00000000e-02 4.53205571e-04]]]
# Figure(1000x600)
# eval_inputs.py:391: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax1.set_ylim(bottom=None)
# ...

# %%
# !python eval_inputs.py 33 fgsm yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# Doing Track $p_{T,rel}$ Ratio [4] now.
# -0.011054902910254896 0.3065083122253418
# eval_inputs.py:324: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# [[[33, 0.01, 8.989296089901633e-05], [33, 0.02, 0.0001524245087402333]]]
# findfont: Font family ['cursive'] not found. Falling back to DejaVu Sans.
# [[[3.30000000e+01 1.00000000e-02 8.98929609e-05]
#   [3.30000000e+01 2.00000000e-02 1.52424509e-04]]]
# Figure(1000x600)
# eval_inputs.py:391: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax1.set_ylim(bottom=None)
# ...

# %%
# !python eval_inputs.py 34 fgsm yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# Doing Track $p_{T,rel}$ Ratio [5] now.
# -0.011047438010573387 0.3061067259311676
# eval_inputs.py:324: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# [[[34, 0.01, 6.880337205087054e-05], [34, 0.02, 0.00011048123126079545]]]
# findfont: Font family ['cursive'] not found. Falling back to DejaVu Sans.
# [[[3.40000000e+01 1.00000000e-02 6.88033721e-05]
#   [3.40000000e+01 2.00000000e-02 1.10481231e-04]]]
# Figure(1000x600)
# eval_inputs.py:391: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax1.set_ylim(bottom=None)
# ...

# %%
# !python eval_inputs.py 35 fgsm yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# Doing Track $p_{T,rel}$ [0] now.
# -0.02298971846699715 13.908773193359375
# eval_inputs.py:324: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# [[[35, 0.01, 0.00012422778053012597], [35, 0.02, 0.0004786233301608449]]]
# findfont: Font family ['cursive'] not found. Falling back to DejaVu Sans.
# [[[3.50000000e+01 1.00000000e-02 1.24227781e-04]
#   [3.50000000e+01 2.00000000e-02 4.78623330e-04]]]
# Figure(1000x600)
# eval_inputs.py:391: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax1.set_ylim(bottom=None)
# ...

# %%
# !python eval_inputs.py 36 fgsm yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# Doing Track $p_{T,rel}$ [1] now.
# -0.023865304179489615 13.115544090270996
# eval_inputs.py:324: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:324: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:327: RuntimeWarning: divide by zero encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in multiply
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# ...

# %%
# !python eval_inputs.py 37 fgsm yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# Doing Track $p_{T,rel}$ [2] now.
# -0.02395284850150347 15.00576187133789
# eval_inputs.py:324: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:324: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:327: RuntimeWarning: divide by zero encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in multiply
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# ...

# %%
# !python eval_inputs.py 38 fgsm yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# Doing Track $p_{T,rel}$ [3] now.
# -0.023728941790759565 13.737826118469238
# eval_inputs.py:324: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# [[[38, 0.01, 2.311410385028186e-05], [38, 0.02, 8.985603648897864e-05]]]
# findfont: Font family ['cursive'] not found. Falling back to DejaVu Sans.
# [[[3.80000000e+01 1.00000000e-02 2.31141039e-05]
#   [3.80000000e+01 2.00000000e-02 8.98560365e-05]]]
# Figure(1000x600)
# eval_inputs.py:391: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax1.set_ylim(bottom=None)
# ...

# %%
# !python eval_inputs.py 39 fgsm yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# Doing Track $p_{T,rel}$ [4] now.
# -0.023032930903136732 14.066042671203613
# eval_inputs.py:324: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# [[[39, 0.01, 1.8177807859928122e-05], [39, 0.02, 7.700193105070717e-05]]]
# findfont: Font family ['cursive'] not found. Falling back to DejaVu Sans.
# [[[3.90000000e+01 1.00000000e-02 1.81778079e-05]
#   [3.90000000e+01 2.00000000e-02 7.70019311e-05]]]
# Figure(1000x600)
# eval_inputs.py:391: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax1.set_ylim(bottom=None)
# ...

# %%
# !python eval_inputs.py 40 fgsm yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# Doing Track $p_{T,rel}$ [5] now.
# -0.022450829148292543 12.700509796142578
# eval_inputs.py:324: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:324: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:327: RuntimeWarning: divide by zero encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in multiply
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# ...

# %%
# !python eval_inputs.py 41 fgsm yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# Doing Track SIP 2D Sig Above Charm now.
# -80.74703002929688 106.42848754882813
# eval_inputs.py:324: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:324: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:327: RuntimeWarning: divide by zero encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in multiply
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# ...

# %%
# !python eval_inputs.py 41 fgsm yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0_adv_tr_eps0.01 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0_adv_tr_eps0.01
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['0.01']
# Loaded model and corresponding criterion.
# Doing Track SIP 2D Sig Above Charm now.
# -81.31600738525391 106.42848754882813
# eval_inputs.py:324: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:324: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:327: RuntimeWarning: divide by zero encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in multiply
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# ...

# %%
# !python eval_inputs.py 42 fgsm yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# Doing Track SIP 2D Sig [0] now.
# -55.441495666503904 180.50937438964843
# eval_inputs.py:324: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:324: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:327: RuntimeWarning: divide by zero encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in multiply
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# ...

# %%
# !python eval_inputs.py 43 fgsm yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# Doing Track SIP 2D Sig [1] now.
# -62.271974334716795 106.77710510253907
# eval_inputs.py:324: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:324: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:327: RuntimeWarning: divide by zero encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in multiply
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# ...

# %%
# !python eval_inputs.py 44 fgsm yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# Doing Track SIP 2D Sig [2] now.
# -67.8127572631836 65.45554901123047
# eval_inputs.py:324: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:324: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:327: RuntimeWarning: divide by zero encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in multiply
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# ...

# %%
# !python eval_inputs.py 45 fgsm yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# Doing Track SIP 2D Sig [3] now.
# -69.5518701171875 48.03749633789062
# eval_inputs.py:324: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:324: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:327: RuntimeWarning: divide by zero encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in multiply
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# ...

# %%
# !python eval_inputs.py 46 fgsm yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# Doing Track SIP 2D Sig [4] now.
# -79.79571319580079 37.873876342773436
# eval_inputs.py:324: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:324: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:327: RuntimeWarning: divide by zero encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in multiply
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# ...

# %%
# !python eval_inputs.py 47 fgsm yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# Doing Track SIP 2D Sig [5] now.
# -75.2500131225586 25.94585205078125
# eval_inputs.py:324: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:324: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:327: RuntimeWarning: divide by zero encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in multiply
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# ...

# %%
# !python eval_inputs.py 48 fgsm yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# Doing Track SIP 2D Val Above Charm now.
# -1.010969409942627 0.20867652654647828
# eval_inputs.py:324: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:324: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:327: RuntimeWarning: divide by zero encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in multiply
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# ...

# %%
# !python eval_inputs.py 48 fgsm yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0_adv_tr_eps0.01 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0_adv_tr_eps0.01
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['0.01']
# Loaded model and corresponding criterion.
# Doing Track SIP 2D Val Above Charm now.
# -1.010969409942627 0.20795721769332887
# eval_inputs.py:324: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:324: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:327: RuntimeWarning: divide by zero encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in multiply
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# ...

# %%
# !python eval_inputs.py 49 fgsm yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# Doing Track SIP 3D Sig Above Charm now.
# -535.4838159179687 176.98622680664062
# eval_inputs.py:324: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:324: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:327: RuntimeWarning: divide by zero encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in multiply
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# ...

# %%
# !python eval_inputs.py 49 fgsm yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0_adv_tr_eps0.01 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0_adv_tr_eps0.01
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['0.01']
# Loaded model and corresponding criterion.
# Doing Track SIP 3D Sig Above Charm now.
# ^C
# Traceback (most recent call last):
#   File "eval_inputs.py", line 1080, in <module>
#     plot(variable,mode=attack,param=[0]+param,minim=min_max[0],maxim=min_max[1],reduced=True)
#   File "eval_inputs.py", line 220, in plot
#     xadv = scalers[variable].inverse_transform(fgsm_attack(epsilon=param[i],sample=all_inputs,targets=all_targets,thismodel=model,thiscriterion=criterion,reduced=reduced)[:,variable].cpu())
#   File "/home/um106329/aisafety/june_21/attack/disturb_inputs.py", line 65, in fgsm_attack
#     preds = thismodel(xadv)
#   File "/home/um106329/miniconda3/envs/my-env/lib/python3.8/site-packages/torch/nn/modules/module.py", line 532, in __call__
#     result = self.forward(*input, **kwargs)
# ...

# %%
# !python eval_inputs.py 50 fgsm yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# Doing Track SIP 3D Sig [0] now.
# -558.1758325195312 558.1292626953125
# eval_inputs.py:324: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:324: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:327: RuntimeWarning: divide by zero encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in multiply
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# ...

# %%
# !python eval_inputs.py 51 fgsm yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# Doing Track SIP 3D Sig [1] now.
# -481.09258056640624 513.891103515625
# eval_inputs.py:324: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:324: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:327: RuntimeWarning: divide by zero encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in multiply
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# ...

# %%
# !python eval_inputs.py 52 fgsm yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# Doing Track SIP 3D Sig [2] now.
# -543.0209252929687 387.474599609375
# eval_inputs.py:324: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:324: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:327: RuntimeWarning: divide by zero encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in multiply
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# ...

# %%
# !python eval_inputs.py 53 fgsm yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# Doing Track SIP 3D Sig [3] now.
# -359.72453857421874 410.832265625
# eval_inputs.py:324: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:324: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:327: RuntimeWarning: divide by zero encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in multiply
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# ...

# %%
# !python eval_inputs.py 54 fgsm yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# Doing Track SIP 3D Sig [4] now.
# -375.82866455078124 383.35774780273437
# eval_inputs.py:324: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:324: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:327: RuntimeWarning: divide by zero encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in multiply
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# ...

# %%
# !python eval_inputs.py 55 fgsm yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# Doing Track SIP 3D Sig [5] now.
# -438.09285522460937 378.16682983398437
# eval_inputs.py:324: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:324: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:327: RuntimeWarning: divide by zero encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in multiply
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# ...

# %%
# !python eval_inputs.py 56 fgsm yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# Doing Track SIP 3D Val Above Charm now.
# -1.901247272491455 0.6865885949134827
# eval_inputs.py:324: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:324: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:327: RuntimeWarning: divide by zero encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in multiply
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# ...

# %%
myvar = 0.00254
mynewvar = f'{myvar:.3f}'
format_wanted = '3f'
exec(f"mynewvar = (f'{str(myvar)+':.'+format_wanted}')")
mynewvar
# Out:
# '0.00254:.3f'

# %%
f'{0.00254:.3f}'
# Out:
# '0.003'

# %%
mynewvar = round(myvar,3)
mynewvar
# Out:
# 0.003

# %%
# !python eval_inputs.py 56 fgsm yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0_adv_tr_eps0.01 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0_adv_tr_eps0.01
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['0.01']
# Loaded model and corresponding criterion.
# Doing Track SIP 3D Val Above Charm now.
# -1.901247272491455 0.6865885949134827
# eval_inputs.py:324: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:324: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:327: RuntimeWarning: divide by zero encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in multiply
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# ...

# %%
# !python eval_inputs.py 57 fgsm yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# Doing Track Sum Jet $\Delta R$ now.
# -0.011000273623503745 0.3106889820098877
# eval_inputs.py:324: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# [[[57, 0.01, 0.00032533524946861704], [57, 0.02, 0.00099050848134412]]]
# findfont: Font family ['cursive'] not found. Falling back to DejaVu Sans.
# [[[5.70000000e+01 1.00000000e-02 3.25335249e-04]
#   [5.70000000e+01 2.00000000e-02 9.90508481e-04]]]
# Figure(1000x600)
# eval_inputs.py:391: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax1.set_ylim(bottom=None)
# ...

# %%
# !python eval_inputs.py 58 fgsm yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# Doing Track Sum Jet $E_T$ Ratio now.
# -0.012588786883279681 3.8814737892150877
# eval_inputs.py:324: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:324: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:327: RuntimeWarning: divide by zero encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in multiply
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# ...

# %%
# !python eval_inputs.py 59 fgsm yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# Doing Vertex Category now.
# -0.01 2.01
# [[[59, 0.01, 0.0], [59, 0.02, 0.0]]]
# findfont: Font family ['cursive'] not found. Falling back to DejaVu Sans.
# [[[5.9e+01 1.0e-02 0.0e+00]
#   [5.9e+01 2.0e-02 0.0e+00]]]
# Figure(1000x600)
# eval_inputs.py:391: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax1.set_ylim(bottom=None)
# eval_inputs.py:640: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax1.set_ylim(bottom=None)
# -0.6 2.6
# [[[59, 0.01, 0.0], [59, 0.02, 0.0]], [[59, 0.01, 0.0], [59, 0.02, 0.0]]]
# [[[5.9e+01 1.0e-02 0.0e+00]
#   [5.9e+01 2.0e-02 0.0e+00]]
#
#  [[5.9e+01 1.0e-02 0.0e+00]
#   [5.9e+01 2.0e-02 0.0e+00]]]
# ...

# %%
# !python eval_inputs.py 60 fgsm yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# Doing Vertex Energy Ratio now.
# -0.011102412468753755 120.2985971069336
# eval_inputs.py:324: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# [[[60, 0.01, 1.9447653615398129e-07], [60, 0.02, 1.7618479385282274e-07]]]
# findfont: Font family ['cursive'] not found. Falling back to DejaVu Sans.
# [[[6.00000000e+01 1.00000000e-02 1.94476536e-07]
#   [6.00000000e+01 2.00000000e-02 1.76184794e-07]]]
# Figure(1000x600)
# eval_inputs.py:388: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax1.set_ylim(bottom=None)
# ...

# %%
# !python eval_inputs.py 61 fgsm yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# Doing Vertex Jet $\Delta R$ now.
# -0.011224752049893141 0.311484614610672
# eval_inputs.py:324: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# [[[61, 0.01, 6.571425031053788e-05], [61, 0.02, 0.00011055195117933376]]]
# findfont: Font family ['cursive'] not found. Falling back to DejaVu Sans.
# [[[6.10000000e+01 1.00000000e-02 6.57142503e-05]
#   [6.10000000e+01 2.00000000e-02 1.10551951e-04]]]
# Figure(1000x600)
# eval_inputs.py:388: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax1.set_ylim(bottom=None)
# ...

# %%
# !python eval_inputs.py 62 fgsm yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# Doing Vertex Mass now.
# 0.009324162974953651 190.61348510742187
# eval_inputs.py:324: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:324: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:327: RuntimeWarning: divide by zero encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in multiply
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# ...

# %%
# !python eval_inputs.py 63 fgsm yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# Doing Jet N Secondary Vertices now.
# -0.01 8.01
# [[[63, 0.01, 0.0], [63, 0.02, 0.0]]]
# findfont: Font family ['cursive'] not found. Falling back to DejaVu Sans.
# [[[6.3e+01 1.0e-02 0.0e+00]
#   [6.3e+01 2.0e-02 0.0e+00]]]
# Figure(1000x600)
# eval_inputs.py:388: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax1.set_ylim(bottom=None)
# eval_inputs.py:497: RuntimeWarning: invalid value encountered in true_divide
#   ratioB  = numB / denomB
# eval_inputs.py:498: RuntimeWarning: invalid value encountered in true_divide
#   ratioBB = numBB / denomBB
# eval_inputs.py:499: RuntimeWarning: invalid value encountered in true_divide
#   ratioC  = numC / denomC
# ...

# %%
# !python eval_inputs.py 64 fgsm yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# Doing Jet N Selected Tracks now.
# -0.01 21.01
# [[[64, 0.01, 0.0], [64, 0.02, 0.0]]]
# findfont: Font family ['cursive'] not found. Falling back to DejaVu Sans.
# [[[6.4e+01 1.0e-02 0.0e+00]
#   [6.4e+01 2.0e-02 0.0e+00]]]
# Figure(1000x600)
# eval_inputs.py:389: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax1.set_ylim(bottom=None)
# eval_inputs.py:499: RuntimeWarning: invalid value encountered in true_divide
#   ratioB  = numB / denomB
# eval_inputs.py:500: RuntimeWarning: invalid value encountered in true_divide
#   ratioBB = numBB / denomBB
# eval_inputs.py:501: RuntimeWarning: invalid value encountered in true_divide
#   ratioC  = numC / denomC
# ...

# %%
# !python eval_inputs.py 65 fgsm yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# Doing Jet N Tracks $\eta_{rel}$ now.
# -0.01 25.01
# eval_inputs.py:324: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# [[[65, 0.01, 0.0], [65, 0.02, 0.0]]]
# findfont: Font family ['cursive'] not found. Falling back to DejaVu Sans.
# [[[6.5e+01 1.0e-02 0.0e+00]
#   [6.5e+01 2.0e-02 0.0e+00]]]
# Figure(1000x600)
# eval_inputs.py:389: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax1.set_ylim(bottom=None)
# eval_inputs.py:420: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# ...

# %%
# !python eval_inputs.py 66 fgsm yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# Doing Vertex N Tracks now.
# -0.01 25.01
# eval_inputs.py:324: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:327: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# [[[66, 0.01, 0.0], [66, 0.02, 0.0]]]
# findfont: Font family ['cursive'] not found. Falling back to DejaVu Sans.
# [[[6.6e+01 1.0e-02 0.0e+00]
#   [6.6e+01 2.0e-02 0.0e+00]]]
# Figure(1000x600)
# eval_inputs.py:389: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax1.set_ylim(bottom=None)
# eval_inputs.py:420: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# ...

# %%
# !python eval_inputs.py 0 noise yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# -2.5797557926177976 2.5832555389404295
# eval_inputs.py:271: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:274: RuntimeWarning: divide by zero encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in multiply
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# [[[0, 0.01, 4.245816656891684e-05], [0, 0.02, 0.0004557480787291028]]]
# findfont: Font family ['cursive'] not found. Falling back to DejaVu Sans.
# [[[0.00000000e+00 1.00000000e-02 4.24581666e-05]
#   [0.00000000e+00 2.00000000e-02 4.55748079e-04]]]
# Figure(1000x600)
# ...

# %%
# !python eval_inputs.py 1 noise yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# 8.17248176574707 792.81615234375
# eval_inputs.py:271: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:271: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:274: RuntimeWarning: divide by zero encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in multiply
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# [[[1, 0.01, 0.00011433307148764964], [1, 0.02, 0.004204680404888461]]]
# ...

# %%
# !python eval_inputs.py 2 noise yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# -0.2472901886701584 944.0995385742187
# eval_inputs.py:271: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:271: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:274: RuntimeWarning: divide by zero encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in multiply
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# [[[2, 0.01, 4.6822753444117355e-06], [2, 0.02, 7.908667913748705e-06]]]
# ...

# %%
# !python eval_inputs.py 3 noise yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# -0.029536888226866724 2.5233876800537107
# eval_inputs.py:271: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:271: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:274: RuntimeWarning: divide by zero encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in multiply
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# ...

# %%
# !python eval_inputs.py 4 noise yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# -3.2013912296295164 941.983388671875
# eval_inputs.py:271: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:271: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:274: RuntimeWarning: divide by zero encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in multiply
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# [[[4, 0.01, 6.372286419133959e-06], [4, 0.02, 2.869958690650595e-05]]]
# ...

# %%
# !python eval_inputs.py 5 noise yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# -0.030264368504285814 14.946551094055176
# eval_inputs.py:271: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# [[[5, 0.01, 8.55978629115519e-06], [5, 0.02, 1.4173564318315372e-05]]]
# findfont: Font family ['cursive'] not found. Falling back to DejaVu Sans.
# [[[5.00000000e+00 1.00000000e-02 8.55978629e-06]
#   [5.00000000e+00 2.00000000e-02 1.41735643e-05]]]
# Figure(1000x600)
# eval_inputs.py:335: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax1.set_ylim(bottom=None)
# ...

# %%
# !python eval_inputs.py 6 noise yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# -0.0643716698884964 5.02923656463623
# eval_inputs.py:271: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:274: RuntimeWarning: divide by zero encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in multiply
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# [[[6, 0.01, 0.000657631152422543], [6, 0.02, 0.015320762227393911]]]
# findfont: Font family ['cursive'] not found. Falling back to DejaVu Sans.
# [[[6.00000000e+00 1.00000000e-02 6.57631152e-04]
#   [6.00000000e+00 2.00000000e-02 1.53207622e-02]]]
# Figure(1000x600)
# ...

# %%
# !python eval_inputs.py 7 noise yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# -0.05304775968194008 5.019989738464355
# eval_inputs.py:271: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:274: RuntimeWarning: divide by zero encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in multiply
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# [[[7, 0.01, 0.013512732685592404], [7, 0.02, 0.04605557009001723]]]
# findfont: Font family ['cursive'] not found. Falling back to DejaVu Sans.
# [[[7.         0.01       0.01351273]
#   [7.         0.02       0.04605557]]]
# Figure(1000x600)
# ...

# %%
# !python eval_inputs.py 8 noise yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# -0.03874317392706871 5.01267744064331
# [[[8, 0.01, 8.325371194047876e-05], [8, 0.02, 0.0003065593330943089]]]
# findfont: Font family ['cursive'] not found. Falling back to DejaVu Sans.
# [[[8.00000000e+00 1.00000000e-02 8.32537119e-05]
#   [8.00000000e+00 2.00000000e-02 3.06559333e-04]]]
# Figure(1000x600)
# eval_inputs.py:335: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax1.set_ylim(bottom=None)
# -0.1 1
# eval_inputs.py:448: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:448: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:451: RuntimeWarning: divide by zero encountered in true_divide
# ...

# %%
# !python eval_inputs.py 9 noise yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# -0.03288608253002167 5.019876728057861
# [[[9, 0.01, 2.362291167753353e-05], [9, 0.02, 0.00019970871863135735]]]
# findfont: Font family ['cursive'] not found. Falling back to DejaVu Sans.
# [[[9.00000000e+00 1.00000000e-02 2.36229117e-05]
#   [9.00000000e+00 2.00000000e-02 1.99708719e-04]]]
# Figure(1000x600)
# eval_inputs.py:335: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax1.set_ylim(bottom=None)
# -0.1 1
# eval_inputs.py:448: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:451: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# ...

# %%
# !python eval_inputs.py 10 noise yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# -0.04558746725320816 5.02536750793457
# [[[10, 0.01, 2.2611214550384475e-05], [10, 0.02, 0.0004427954696806427]]]
# findfont: Font family ['cursive'] not found. Falling back to DejaVu Sans.
# [[[1.00000000e+01 1.00000000e-02 2.26112146e-05]
#   [1.00000000e+01 2.00000000e-02 4.42795470e-04]]]
# Figure(1000x600)
# eval_inputs.py:335: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax1.set_ylim(bottom=None)
# -0.1 1
# eval_inputs.py:448: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:448: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:451: RuntimeWarning: divide by zero encountered in true_divide
# ...

# %%
# !python eval_inputs.py 11 noise yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# -0.0386702960729599 5.009378204345703
# [[[11, 0.01, 2.2131293882513528e-05], [11, 0.02, 7.000789152449691e-05]]]
# findfont: Font family ['cursive'] not found. Falling back to DejaVu Sans.
# [[[1.10000000e+01 1.00000000e-02 2.21312939e-05]
#   [1.10000000e+01 2.00000000e-02 7.00078915e-05]]]
# Figure(1000x600)
# eval_inputs.py:335: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax1.set_ylim(bottom=None)
# -0.1 1
# eval_inputs.py:448: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:448: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:451: RuntimeWarning: divide by zero encountered in true_divide
# ...

# %%
# !python eval_inputs.py 12 noise yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# -0.01296353455632925 0.31541378259658814
# eval_inputs.py:271: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:271: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:274: RuntimeWarning: divide by zero encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in multiply
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# ...

# %%
# !python eval_inputs.py 13 noise yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# -0.013642450086772442 0.31529993772506715
# eval_inputs.py:271: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:271: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:274: RuntimeWarning: divide by zero encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in multiply
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# ...

# %%
# !python eval_inputs.py 14 noise yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# -0.01395383033901453 0.314705023765564
# eval_inputs.py:271: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:271: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:274: RuntimeWarning: divide by zero encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in multiply
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# [[[14, 0.01, 0.00012938368605533727], [14, 0.02, 0.0003833728347451945]]]
# ...

# %%
# !python eval_inputs.py 15 noise yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# -0.014027754999697209 0.3154400682449341
# eval_inputs.py:271: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:271: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:274: RuntimeWarning: divide by zero encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in multiply
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# ...

# %%
# !python eval_inputs.py 16 noise yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# -0.013920629620552063 0.315639386177063
# eval_inputs.py:271: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:271: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:274: RuntimeWarning: divide by zero encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in multiply
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# ...

# %%
# !python eval_inputs.py 17 noise yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# -0.012242690417915583 0.3138623332977295
# eval_inputs.py:271: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:271: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:274: RuntimeWarning: divide by zero encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in multiply
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# ...

# %%
# !python eval_inputs.py 18 noise yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# -4.791981945037842 8.261704216003418
# eval_inputs.py:271: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:271: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:274: RuntimeWarning: divide by zero encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in multiply
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# [[[18, 0.01, 5.0612478287292864e-05], [18, 0.02, 0.00010168007396526794]]]
# ...

# %%
# !python eval_inputs.py 19 noise yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# -4.675261745452881 8.505492935180664
# eval_inputs.py:271: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:271: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:274: RuntimeWarning: divide by zero encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in multiply
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# [[[19, 0.01, 3.9118410160126695e-05], [19, 0.02, 8.722596065406799e-05]]]
# ...

# %%
# !python eval_inputs.py 20 noise yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# -3.9242050743103025 8.759796867370605
# eval_inputs.py:271: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# [[[20, 0.01, 1.3562990509123435e-05], [20, 0.02, 1.6944239955662666e-05]]]
# findfont: Font family ['cursive'] not found. Falling back to DejaVu Sans.
# [[[2.00000000e+01 1.00000000e-02 1.35629905e-05]
#   [2.00000000e+01 2.00000000e-02 1.69442400e-05]]]
# Figure(1000x600)
# eval_inputs.py:335: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax1.set_ylim(bottom=None)
# ...

# %%
# !python eval_inputs.py 21 noise yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# -4.306250820159912 8.030148277282715
# eval_inputs.py:271: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# [[[21, 0.01, 1.199415198009311e-05], [21, 0.02, 1.51970230085104e-05]]]
# findfont: Font family ['cursive'] not found. Falling back to DejaVu Sans.
# [[[2.1000000e+01 1.0000000e-02 1.1994152e-05]
#   [2.1000000e+01 2.0000000e-02 1.5197023e-05]]]
# Figure(1000x600)
# eval_inputs.py:335: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax1.set_ylim(bottom=None)
# ...

# %%
# !python eval_inputs.py 22 noise yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# -0.08102172821760177 0.01113219814375043
# eval_inputs.py:271: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:271: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:274: RuntimeWarning: divide by zero encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in multiply
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# [[[22, 0.01, 0.005674665135774107], [22, 0.02, 0.01704322598158585]]]
# ...

# %%
# !python eval_inputs.py 23 noise yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# -0.08100672274827957 0.011648473320528865
# eval_inputs.py:271: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:271: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:274: RuntimeWarning: divide by zero encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in multiply
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# ...

# %%
# !python eval_inputs.py 24 noise yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# -0.0810114762187004 0.012287366427481175
# eval_inputs.py:271: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:271: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:274: RuntimeWarning: divide by zero encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in multiply
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# [[[24, 0.01, 0.015132899766574507], [24, 0.02, 0.049924367894179804]]]
# ...

# %%
# !python eval_inputs.py 25 noise yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# -0.08100782543420791 0.012667229855433107
# eval_inputs.py:271: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:271: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:274: RuntimeWarning: divide by zero encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in multiply
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# [[[25, 0.01, 0.002449894775221578], [25, 0.02, 0.022129392917233343]]]
# ...

# %%
# !python eval_inputs.py 26 noise yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# -0.08133053243160247 0.01259883119724691
# eval_inputs.py:271: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:271: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:274: RuntimeWarning: divide by zero encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in multiply
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# [[[26, 0.01, 0.003809272618754277], [26, 0.02, 0.021710333756933264]]]
# ...

# %%
# !python eval_inputs.py 27 noise yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# -0.08116580009460449 0.012420592587441206
# eval_inputs.py:271: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:271: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:274: RuntimeWarning: divide by zero encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in multiply
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# [[[27, 0.01, 0.004740370614166227], [27, 0.02, 0.017743880466518563]]]
# ...

# %%
# !python eval_inputs.py 28 noise yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# -4.959655532836914 252.452138671875
# eval_inputs.py:271: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:271: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:274: RuntimeWarning: divide by zero encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in multiply
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# [[[28, 0.01, 0.001404695492364531], [28, 0.02, 0.0011161565222658982]]]
# ...

# %%
# !python eval_inputs.py 29 noise yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# -0.012971756970509887 0.3083834445476532
# eval_inputs.py:271: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:271: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:274: RuntimeWarning: divide by zero encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in multiply
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# ...

# %%
# !python eval_inputs.py 30 noise yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# -0.01295401830226183 0.3070678210258484
# eval_inputs.py:271: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# [[[30, 0.01, 7.372030748207431e-05], [30, 0.02, 0.00012479456249633736]]]
# findfont: Font family ['cursive'] not found. Falling back to DejaVu Sans.
# [[[3.00000000e+01 1.00000000e-02 7.37203075e-05]
#   [3.00000000e+01 2.00000000e-02 1.24794562e-04]]]
# Figure(1000x600)
# eval_inputs.py:335: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax1.set_ylim(bottom=None)
# ...

# %%
# !python eval_inputs.py 31 noise yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# -0.013289959859102965 0.3074551320075989
# eval_inputs.py:271: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# [[[31, 0.01, 7.893764466996577e-05], [31, 0.02, 0.00014725473944966953]]]
# findfont: Font family ['cursive'] not found. Falling back to DejaVu Sans.
# [[[3.10000000e+01 1.00000000e-02 7.89376447e-05]
#   [3.10000000e+01 2.00000000e-02 1.47254739e-04]]]
# Figure(1000x600)
# eval_inputs.py:335: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax1.set_ylim(bottom=None)
# ...

# %%
# !python eval_inputs.py 32 noise yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# -0.013209119429811835 0.30724469780921937
# eval_inputs.py:271: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# [[[32, 0.01, 5.4201599480263375e-05], [32, 0.02, 9.905565802257514e-05]]]
# findfont: Font family ['cursive'] not found. Falling back to DejaVu Sans.
# [[[3.20000000e+01 1.00000000e-02 5.42015995e-05]
#   [3.20000000e+01 2.00000000e-02 9.90556580e-05]]]
# Figure(1000x600)
# eval_inputs.py:335: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax1.set_ylim(bottom=None)
# ...

# %%
# !python eval_inputs.py 33 noise yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# -0.012919433172792196 0.30688385128974915
# eval_inputs.py:271: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# [[[33, 0.01, 5.0888742634801356e-05], [33, 0.02, 8.286784961460769e-05]]]
# findfont: Font family ['cursive'] not found. Falling back to DejaVu Sans.
# [[[3.30000000e+01 1.00000000e-02 5.08887426e-05]
#   [3.30000000e+01 2.00000000e-02 8.28678496e-05]]]
# Figure(1000x600)
# eval_inputs.py:335: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax1.set_ylim(bottom=None)
# ...

# %%
# !python eval_inputs.py 34 noise yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# -0.012388723194599152 0.3071034348011017
# eval_inputs.py:271: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# [[[34, 0.01, 3.531654112723806e-05], [34, 0.02, 5.5893368025360636e-05]]]
# findfont: Font family ['cursive'] not found. Falling back to DejaVu Sans.
# [[[3.40000000e+01 1.00000000e-02 3.53165411e-05]
#   [3.40000000e+01 2.00000000e-02 5.58933680e-05]]]
# Figure(1000x600)
# eval_inputs.py:335: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax1.set_ylim(bottom=None)
# ...

# %%
# !python eval_inputs.py 35 noise yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# -0.050243882685899736 13.894550094604492
# eval_inputs.py:271: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:271: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:274: RuntimeWarning: divide by zero encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in multiply
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# ...

# %%
# !python eval_inputs.py 36 noise yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# -0.044092318266630175 13.101320991516113
# eval_inputs.py:271: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# [[[36, 0.01, 8.016095154020011e-06], [36, 0.02, 1.410080635439384e-05]]]
# findfont: Font family ['cursive'] not found. Falling back to DejaVu Sans.
# [[[3.60000000e+01 1.00000000e-02 8.01609515e-06]
#   [3.60000000e+01 2.00000000e-02 1.41008064e-05]]]
# Figure(1000x600)
# eval_inputs.py:335: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax1.set_ylim(bottom=None)
# ...

# %%
# !python eval_inputs.py 37 noise yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# -0.042680805772542955 14.993423233032226
# eval_inputs.py:271: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:271: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:274: RuntimeWarning: divide by zero encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in multiply
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# ...

# %%
# !python eval_inputs.py 38 noise yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# -0.04620603308081627 13.725580940246582
# eval_inputs.py:271: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:271: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:274: RuntimeWarning: divide by zero encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in multiply
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# ...

# %%
# !python eval_inputs.py 39 noise yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# -0.03697347290813923 14.062770614624023
# eval_inputs.py:271: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:271: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:274: RuntimeWarning: divide by zero encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in multiply
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# ...

# %%
# !python eval_inputs.py 40 noise yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# -0.03596212923526764 12.687130699157715
# eval_inputs.py:271: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:271: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:274: RuntimeWarning: divide by zero encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in multiply
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# [[[40, 0.01, 9.28682712820893e-06], [40, 0.02, 1.1155427253057295e-05]]]
# ...

# %%
# !python eval_inputs.py 41 noise yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# -81.43276000976563 106.40816284179688
# eval_inputs.py:271: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:271: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:274: RuntimeWarning: divide by zero encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in multiply
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# [[[41, 0.01, 0.0022768784602660076], [41, 0.02, 0.026331267002764756]]]
# ...

# %%
# !python eval_inputs.py 42 noise yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# -55.441495666503904 180.28333068847655
# eval_inputs.py:271: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# [[[42, 0.01, 1.5331406807682964e-05], [42, 0.02, 0.00010519548845032133]]]
# findfont: Font family ['cursive'] not found. Falling back to DejaVu Sans.
# [[[4.20000000e+01 1.00000000e-02 1.53314068e-05]
#   [4.20000000e+01 2.00000000e-02 1.05195488e-04]]]
# Figure(1000x600)
# eval_inputs.py:335: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax1.set_ylim(bottom=None)
# ...

# %%
# !python eval_inputs.py 43 noise yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# -62.271974334716795 106.3939340209961
# eval_inputs.py:271: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:271: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:274: RuntimeWarning: divide by zero encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in multiply
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# [[[43, 0.01, 0.00023723887886617398], [43, 0.02, 0.003326177033975239]]]
# ...

# %%
# !python eval_inputs.py 44 noise yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# -67.8127572631836 65.4467904663086
# eval_inputs.py:271: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:271: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:274: RuntimeWarning: divide by zero encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in multiply
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# [[[44, 0.01, 0.0010478570903620708], [44, 0.02, 0.016311699591150915]]]
# ...

# %%
# !python eval_inputs.py 45 noise yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# -69.5518701171875 48.60847259521484
# eval_inputs.py:271: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:271: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:274: RuntimeWarning: divide by zero encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in multiply
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# [[[45, 0.01, 0.0030219168111734443], [45, 0.02, 0.03243544734861738]]]
# ...

# %%
# !python eval_inputs.py 46 noise yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# -79.08316589355469 38.743680725097654
# eval_inputs.py:271: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:271: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:274: RuntimeWarning: divide by zero encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in multiply
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# [[[46, 0.01, 0.002854362157543571], [46, 0.02, 0.02995173659274589]]]
# ...

# %%
# !python eval_inputs.py 47 noise yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# -74.80866027832032 26.668050537109377
# eval_inputs.py:271: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:271: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:274: RuntimeWarning: divide by zero encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in multiply
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# [[[47, 0.01, 0.002502585781765137], [47, 0.02, 0.02061873602432002]]]
# ...

# %%
# !python eval_inputs.py 48 noise yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# -1.010969409942627 0.2036664879322052
# eval_inputs.py:271: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:271: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:274: RuntimeWarning: divide by zero encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in multiply
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# [[[48, 0.01, 0.05795578535368072], [48, 0.02, 0.24527608566862794]]]
# ...

# %%
# !python eval_inputs.py 49 noise yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# -540.9268090820312 179.84482360839843
# eval_inputs.py:271: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:271: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:274: RuntimeWarning: divide by zero encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in multiply
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# [[[49, 0.01, 0.004279390236079672], [49, 0.02, 0.05188682591776967]]]
# ...

# %%
# !python eval_inputs.py 50 noise yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# -557.9557397460937 557.0653588867187
# eval_inputs.py:271: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# [[[50, 0.01, 0.00021226790325519712], [50, 0.02, 0.0002674918418591197]]]
# findfont: Font family ['cursive'] not found. Falling back to DejaVu Sans.
# [[[5.00000000e+01 1.00000000e-02 2.12267903e-04]
#   [5.00000000e+01 2.00000000e-02 2.67491842e-04]]]
# Figure(1000x600)
# eval_inputs.py:335: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax1.set_ylim(bottom=None)
# ...

# %%
# !python eval_inputs.py 51 noise yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# -482.46269775390624 516.750478515625
# eval_inputs.py:271: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:271: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:274: RuntimeWarning: divide by zero encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in multiply
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# [[[51, 0.01, 0.0028574800448676425], [51, 0.02, 0.03353494729743423]]]
# ...

# %%
# !python eval_inputs.py 52 noise yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# -548.1599633789062 386.437001953125
# eval_inputs.py:271: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:271: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:274: RuntimeWarning: divide by zero encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in multiply
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# [[[52, 0.01, 0.0060831497629891896], [52, 0.02, 0.06721016137607551]]]
# ...

# %%
# !python eval_inputs.py 53 noise yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# -360.6028955078125 410.58623291015624
# eval_inputs.py:271: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:271: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:274: RuntimeWarning: divide by zero encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in multiply
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# [[[53, 0.01, 0.018544901681295783], [53, 0.02, 0.08483556420891937]]]
# ...

# %%
# !python eval_inputs.py 54 noise yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# -374.0196435546875 383.9747521972656
# eval_inputs.py:271: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:271: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:274: RuntimeWarning: divide by zero encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in multiply
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# [[[54, 0.01, 0.014466409110157891], [54, 0.02, 0.0698054946805044]]]
# ...

# %%
# !python eval_inputs.py 55 noise yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# -438.09285522460937 375.89693237304687
# eval_inputs.py:271: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:271: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:274: RuntimeWarning: divide by zero encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in multiply
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# [[[55, 0.01, 0.0028176622971571703], [55, 0.02, 0.019512177295923708]]]
# ...

# %%
# !python eval_inputs.py 56 noise yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# -1.901247272491455 0.6935814714431763
# eval_inputs.py:271: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:271: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:274: RuntimeWarning: divide by zero encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in multiply
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# [[[56, 0.01, 0.04944778131000325], [56, 0.02, 0.23424852345111175]]]
# ...

# %%
# !python eval_inputs.py 57 noise yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# -0.012108733635395766 0.31212223529815675
# eval_inputs.py:271: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# [[[57, 0.01, 4.3865685025966034e-05], [57, 0.02, 0.0001260658445486123]]]
# findfont: Font family ['cursive'] not found. Falling back to DejaVu Sans.
# [[[5.70000000e+01 1.00000000e-02 4.38656850e-05]
#   [5.70000000e+01 2.00000000e-02 1.26065845e-04]]]
# Figure(1000x600)
# eval_inputs.py:335: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax1.set_ylim(bottom=None)
# ...

# %%
# !python eval_inputs.py 58 noise yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# -0.013819503588601947 3.8814737892150877
# eval_inputs.py:271: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:271: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:274: RuntimeWarning: divide by zero encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in multiply
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# ...

# %%
# !python eval_inputs.py 59 noise yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# -0.01 2.01
# [[[59, 0.01, 0.0], [59, 0.02, 0.0]]]
# findfont: Font family ['cursive'] not found. Falling back to DejaVu Sans.
# [[[5.9e+01 1.0e-02 0.0e+00]
#   [5.9e+01 2.0e-02 0.0e+00]]]
# Figure(1000x600)
# eval_inputs.py:335: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax1.set_ylim(bottom=None)
# -0.6 2.6
# [[[59, 0.01, 0.0], [59, 0.02, 0.0]], [[59, 0.01, 0.0], [59, 0.02, 0.0]]]
# [[[5.9e+01 1.0e-02 0.0e+00]
#   [5.9e+01 2.0e-02 0.0e+00]]
#
#  [[5.9e+01 1.0e-02 0.0e+00]
#   [5.9e+01 2.0e-02 0.0e+00]]]
# eval_inputs.py:509: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax1.set_ylim(bottom=None)

# %%
# !python eval_inputs.py 60 noise yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# -0.019750748053193094 120.29342437744141
# eval_inputs.py:271: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# [[[60, 0.01, 1.2389786317490613e-07], [60, 0.02, 3.763234617204625e-08]]]
# findfont: Font family ['cursive'] not found. Falling back to DejaVu Sans.
# [[[6.00000000e+01 1.00000000e-02 1.23897863e-07]
#   [6.00000000e+01 2.00000000e-02 3.76323462e-08]]]
# Figure(1000x600)
# eval_inputs.py:335: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax1.set_ylim(bottom=None)
# ...

# %%
# !python eval_inputs.py 61 noise yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# -0.0124656574241817 0.31342793464660645
# eval_inputs.py:271: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:271: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:274: RuntimeWarning: divide by zero encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in multiply
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# ...

# %%
# !python eval_inputs.py 62 noise yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# -0.07376149505376815 190.53316284179687
# eval_inputs.py:271: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:271: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:274: RuntimeWarning: divide by zero encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in multiply
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# ...

# %%
# !python eval_inputs.py 63 noise yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# -0.01 8.01
# [[[63, 0.01, 0.0], [63, 0.02, 0.0]]]
# findfont: Font family ['cursive'] not found. Falling back to DejaVu Sans.
# [[[6.3e+01 1.0e-02 0.0e+00]
#   [6.3e+01 2.0e-02 0.0e+00]]]
# Figure(1000x600)
# eval_inputs.py:335: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax1.set_ylim(bottom=None)
# -0.5 8.01
# [[[63, 0.01, 0.0], [63, 0.02, 0.0]], [[63, 0.01, 0.0], [63, 0.02, 0.0]]]
# [[[6.3e+01 1.0e-02 0.0e+00]
#   [6.3e+01 2.0e-02 0.0e+00]]
#
#  [[6.3e+01 1.0e-02 0.0e+00]
#   [6.3e+01 2.0e-02 0.0e+00]]]
# eval_inputs.py:509: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax1.set_ylim(bottom=None)

# %%
# !python eval_inputs.py 64 noise yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# -0.01 21.01
# [[[64, 0.01, 0.0], [64, 0.02, 0.0]]]
# findfont: Font family ['cursive'] not found. Falling back to DejaVu Sans.
# [[[6.4e+01 1.0e-02 0.0e+00]
#   [6.4e+01 2.0e-02 0.0e+00]]]
# Figure(1000x600)
# eval_inputs.py:335: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax1.set_ylim(bottom=None)
# -0.5 21.01
# [[[64, 0.01, 0.0], [64, 0.02, 0.0]], [[64, 0.01, 0.0], [64, 0.02, 0.0]]]
# [[[6.4e+01 1.0e-02 0.0e+00]
#   [6.4e+01 2.0e-02 0.0e+00]]
#
#  [[6.4e+01 1.0e-02 0.0e+00]
#   [6.4e+01 2.0e-02 0.0e+00]]]
# eval_inputs.py:509: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax1.set_ylim(bottom=None)

# %%
# !python eval_inputs.py 65 noise yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# -0.01 25.01
# eval_inputs.py:271: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# [[[65, 0.01, 0.0], [65, 0.02, 0.0]]]
# findfont: Font family ['cursive'] not found. Falling back to DejaVu Sans.
# [[[6.5e+01 1.0e-02 0.0e+00]
#   [6.5e+01 2.0e-02 0.0e+00]]]
# Figure(1000x600)
# eval_inputs.py:335: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax1.set_ylim(bottom=None)
# eval_inputs.py:352: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# ...

# %%
# !python eval_inputs.py 66 noise yes '0.01,0.02' 278 200 _ptetaflavloss_focalloss_gamma25.0 0.001 -1 yes
# Out:
# Evaluate training at epoch 200
# With weighting method _ptetaflavloss_focalloss_gamma25.0
# gamma ['25.0']
# alpha ['25.0']
# epsilon ['_ptetaflavloss_focalloss_gamma25.0']
# Loaded model and corresponding criterion.
# -0.01 25.01
# eval_inputs.py:271: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# eval_inputs.py:274: RuntimeWarning: invalid value encountered in true_divide
#   ratio_err = np.sqrt((num_err/denom)**2+(num/(denom**2)*denom_err)**2)
# [[[66, 0.01, 0.0], [66, 0.02, 0.0]]]
# findfont: Font family ['cursive'] not found. Falling back to DejaVu Sans.
# [[[6.6e+01 1.0e-02 0.0e+00]
#   [6.6e+01 2.0e-02 0.0e+00]]]
# Figure(1000x600)
# eval_inputs.py:335: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax1.set_ylim(bottom=None)
# eval_inputs.py:352: RuntimeWarning: invalid value encountered in true_divide
#   ratio = num / denom
# ...

# %% [markdown]
# #### Sanity check: what's happening to integer variables
# and why no bin at 2 for vertexCat

# %%
import matplotlib.pyplot as plt
import torch

# %%
ins = torch.load('/hpcwork/um106329/june_21/scaled_QCD/test_inputs_0_with_default_0.001.pt')

# %%
ins[:,59]
# Out:
# array([ 0.7246,  0.7246,  0.7246, ...,  0.7246, -1.423 ,  0.7246],
#       dtype=float16)

# %%
scalers = [torch.load(f'/hpcwork/um106329/june_21/scaler_{i}_with_default_0.001.pt') for i in range(67)]

# %%
ins_back = scalers[59].inverse_transform(ins[:,59].cpu())

# %%
ins_back
# Out:
# array([2.00e+00, 2.00e+00, 2.00e+00, ..., 2.00e+00, 8.16e-05, 2.00e+00],
#       dtype=float16)

# %% [markdown]
# ### Downloading all input shapes at once

# %%
# !tar czf inputs_pdf.tar.gz inputs/*.pdf

# %%
# !tar czf inputs_svg.tar.gz inputs/*.svg

# %% [markdown]
# then download the compressed folder and untar at personal device

# %% [markdown]
# ## v2

# %%
# !tar czf inputs_v2_pdf.tar.gz inputs/v2/*.pdf

# %%
# !tar czf inputs_v2_svg.tar.gz inputs/v2/*.svg

# %%
# !tar czf inputs_v2_split_by_flav_pdf.tar.gz inputs/v2/split_by_flav/*.pdf

# %%
# !tar czf inputs_v2_split_by_flav_svg.tar.gz inputs/v2/split_by_flav/*.svg
